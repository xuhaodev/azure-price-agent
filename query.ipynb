# %%
#!/usr/bin/env python3
import requests
import json
from tabulate import tabulate 


def build_pricing_table(json_data, table_data):
    for item in json_data['Items']:
        meter = item['meterName']
        table_data.append([item['armSkuName'], item['retailPrice'], item['unitOfMeasure'], item['armRegionName'], meter, item['productName']])
        
def main():
    table_data = []
    table_data.append(['SKU', 'Retail Price', 'Unit of Measure', 'Region', 'Meter', 'Product Name'])
    
    api_url = "https://prices.azure.com/api/retail/prices?api-version=2021-10-01-preview"
    query = "armRegionName eq 'eastus2' and contains(tolower(meterName), 'd8s') and contains(tolower(meterName), 'v4')"
    #query = "meterid eq 'c49bbc0f-4a04-5700-b71a-92aa11ab9cee'"
    response = requests.get(api_url, params={'$filter': query})
    json_data = json.loads(response.text)
    
    build_pricing_table(json_data, table_data)
    nextPage = json_data['NextPageLink']
    
    while(nextPage):
        response = requests.get(nextPage)
        json_data = json.loads(response.text)
        nextPage = json_data['NextPageLink']
        build_pricing_table(json_data, table_data)

    print(tabulate(table_data, headers='firstrow', tablefmt='psql'))
    
if __name__ == "__main__":
    main()
# Out:
# +------------------------------------------------------------+----------------+-------------------+----------+-----------------------+-------------------------------------------------------+
# | SKU                                                        |   Retail Price | Unit of Measure   | Region   | Meter                 | Product Name                                          |
# |------------------------------------------------------------+----------------+-------------------+----------+-----------------------+-------------------------------------------------------|
# | Standard_D8s_v4                                            |       0.752    | 1 Hour            | eastus2  | D8s v4                | Virtual Machines Dsv4 Series Windows                  |
# | Standard_D8s_v4                                            |       0.384    | 1 Hour            | eastus2  | D8s v4                | Virtual Machines Dsv4 Series Windows                  |
# | Standard_D8s_v4                                            |       0.11305  | 1 Hour            | eastus2  | D8s v4 Spot           | Virtual Machines Dsv4 Series                          |
# | Standard_D8s_v4                                            |       0.0768   | 1 Hour            | eastus2  | D8s v4 Low Priority   | Virtual Machines Dsv4 Series                          |
# | Standard_D8s_v4                                            |       0.221389 | 1 Hour            | eastus2  | D8s v4 Spot           | Virtual Machines Dsv4 Series Windows                  |
# | Standard_D8s_v4                                            |       0.11305  | 1 Hour            | eastus2  | D8s v4 Spot           | Virtual Machines Dsv4 Series Windows                  |
# | Azure_Managed_Instance_for_Apache_Cassandra_Compute_D8s_v4 |       0.384    | 1 Hour            | eastus2  | D8s_v4 vCore          | Azure Managed Instance for Apache Cassandra - Compute |
# | Standard_D8s_v4                                            |       0.301    | 1 Hour            | eastus2  | D8s v4 Low Priority   | Virtual Machines Dsv4 Series Windows                  |
# | Standard_D8s_v4                                            |       0.0768   | 1 Hour            | eastus2  | D8s v4 Low Priority   | Virtual Machines Dsv4 Series Windows                  |
# | Standard_D8s_v4                                            |       0.384    | 1 Hour            | eastus2  | D8s v4                | Virtual Machines Dsv4 Series                          |
# | Standard_D8s_v4                                            |    1985        | 1 Hour            | eastus2  | D8s v4                | Virtual Machines Dsv4 Series                          |
# | Standard_D8s_v4                                            |    3835        | 1 Hour            | eastus2  | D8s v4                | Virtual Machines Dsv4 Series                          |
# | Standard_D8s_v4                                            |       0.48     | 1 Hour            | eastus2  | Standard_D8s_v4 vCore | Azure Managed Instance for Apache Cassandra - Compute |
# +------------------------------------------------------------+----------------+-------------------+----------+-----------------------+-------------------------------------------------------+
